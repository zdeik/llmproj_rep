# %%
import langchain
langchain.__version__
# Out:
# '0.3.27'

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model='gpt-4o-mini')
llm
# Out:
# ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x000001886085A7E0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x0000018861E0E660>, root_client=<openai.OpenAI object at 0x00000188603619D0>, root_async_client=<openai.AsyncOpenAI object at 0x0000018860859010>, model_name='gpt-4o-mini', model_kwargs={}, openai_api_key=SecretStr('**********'))

# %%
messages = [
    ("system", "당신은 서울의 음식과 문화 전문가입니다."),
    ("human", "서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5개를 추천해 주세요.") 
]
res = llm.invoke(messages)

# %%
res.content
# Out:
# '서울에서 대표적인 음식을 맛볼 수 있는 레스토랑 다섯 곳을 추천해 드리겠습니다.\n\n1. **광장시장 – 마담밍(Madame M)**  \n   이곳은 전통적인 한국 길거리 음식을 현대적으로 재해석한 메뉴를 제공합니다. 특히 마늘을 곁들인 다양한 전통 전과 함께 손색 없는 비빔밥을 맛볼 수 있습니다.\n\n2. **백두산 (Baekdusan)**  \n   한정식 전문 레스토랑으로, 다양한 전통 반찬과 함께 고급 한식을 제공합니다. 정갈한 분위기에서 전통적인 한국 요리를 맛볼 수 있습니다.\n\n3. **토속촌삼계탕 (Tosokchon Samgyetang)**  \n   삼계탕의 명소로 유명한 이곳은 신선한 재료로 만든 삼계탕을 제공합니다. 한약재와 영양 가득 찬 닭고기로 맛있고 건강한 식사를 즐길 수 있습니다.\n\n4. **신촌 골뱅이**  \n   서울의 해산물 요리를 대표하는 곳 중 하나로, 맛있는 골뱅이 무침과 함께 소주를 즐길 수 있습니다. 특히, 그들의 비밀 소스가 독특한 맛을 선사합니다.\n\n5. **해장국집 (Haegukjeongol)**  \n   서울의 전통적인 해장국을 맛볼 수 있는 곳으로, 다양한 종류의 해장국과 함께 볶음밥이 인기입니다. 숙취해소에 좋은 메뉴로 사랑받고 있습니다.\n\n각 레스토랑은 서울의 음식 문화와 전통을 느낄 수 있는 장소로, 현지인들과 관광객 모두에게 인기가 많습니다. 맛있는 음식과 함께 서울의 멋진 문화를 경험해 보세요!'

# %%
messages = [
    [("system", "당신은 서울의 음식 전문가입니다."), ("human", "서울 광장시장에서 먹을 만한 길거리 음식들을 소개해 주세요")],
    [("system", "당신은 서울의 문화 전문가입니다."), ("human", "서울에서 데이트할 때 가 볼 만한 분위기 좋은 곳들을 알려 주세요")] 
]
response = llm.batch(messages)
response
# Out:
# [AIMessage(content='서울 광장시장은 다양한 맛있는 길거리 음식으로 유명합니다. 다음은 광장시장에서 꼭 먹어봐야 할 몇 가지 길거리 음식입니다:\n\n1. **떡볶이**: 매콤달콤한 소스에 푹 담가진 쌀떡과 어묵, 야채가 함께 나오는 인기 있는 간식입니다.\n\n2. **순대**: 한국의 전통 순대는 돼지의 창자에 찹쌀, 당면, 채소 등을 넣어 만든 음식으로, 쫄깃한 식감이 매력적입니다. 보통 간장 소스나 고추장을 찍어 먹습니다.\n\n3. **핫바**: 어묵으로 만든 바삭한 튀김으로, 다양한 속재료가 들어간 것이 특징입니다. 간편하게 먹기 좋고, 따뜻하게 제공됩니다.\n\n4. **튀김**: 각종 채소와 해산물을 튀긴 음식으로, 바삭하고 고소한 맛이 일품입니다. 특히 새우튀김이 인기가 많습니다.\n\n5. **계란빵**: 겉은 부드러운 빵에 계란이 푹 담겨 있는 간식으로, 따뜻하고 부드러운 식감이 좋습니다.\n\n6. **야채전**: 다양한 채소를 섞어 부친 전으로, 바삭하고 담백한 맛이 특징입니다. 간장 소스와 함께 즐기면 더욱 맛있습니다.\n\n7. **김밥**: 다양한 재료를 넣어 만든 김밥도 좋은 선택입니다. 간편하게 먹을 수 있어 길거리에서 인기입니다.\n\n8. **과일 주스**: 신선한 과일로 만든 주스나 스무디는 더운 날씨에 상큼하게 마시기 좋은 음식입니다.\n\n광장시장에서 다양한 길거리 음식을 즐기며 한국의 맛을 경험해 보세요!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 421, 'prompt_tokens': 36, 'total_tokens': 457, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-C7CnHPusj7Qjx4sVMX5NDDvrOeK9f', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--5dae9841-ec61-4370-af3f-9fe4853008ec-0', usage_metadata={'input_tokens': 36, 'output_tokens': 421, 'total_tokens': 457, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='서울은 데이트를 즐기기에 정말 멋진 장소가 많습니다. 분위기 좋은 곳들을 몇 가지 추천해드릴게요.\n\n1. **한강공원**: 저녁 노을에 따라 걷거나 자전거를 탈 수 있는 아름다운 공원입니다. 특히 선유도 공원은 분위기가 좋고 아기자기한 포토존도 많아요.\n\n2. **북촌 한옥마을**: 전통 한옥이 자아내는 고즈넉한 분위기 속에서 산책하며 서로의 이야기를 나눌 수 있는 곳입니다. 앙증맞은 찻집도 많아 차 한 잔을 즐기기에도 좋습니다.\n\n3. **익선동**: 현대적인 감각과 전통이 어우러진 곳으로, 예쁜 카페와 레스토랑들이 많아 데이트하기 좋은 곳입니다. 각종 소품샵도 있어 구경하기에 좋습니다.\n\n4. **가로수길**: 패션과 트렌드의 중심지로, 스타일리시한 카페와 레스토랑이 많습니다. 거리 자체도 여유롭게 걸어다니기 좋습니다.\n\n5. **남산 서울타워**: 케이블카를 타고 올라가거나, 산책로를 따라 올라가면서 서울의 전경을 즐길 수 있습니다. 특히 해질 무렵의 경치가 아름다워 로맨틱한 분위기를 만끽할 수 있습니다.\n\n6. **홍대**: 다양한 예술과 문화를 즐길 수 있는 곳으로, 거리공연이나 독특한 카페가 많습니다. 밤에는 활기찬 분위기 속에서 바나 클럽도 즐길 수 있습니다.\n\n7. **이태원**: 다양한 문화가 공존하는 이곳에서는 세계 각국의 음식을 맛볼 수 있는 레스토랑도 많고, 분위기 좋은 바나 카페도 많아 색다른 데이트를 즐길 수 있습니다.\n\n이 외에도 서울에는 많은 숨겨진 명소와 매력적인 장소가 있으니, 둘만의 특별한 추억을 만들어보세요!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 458, 'prompt_tokens': 37, 'total_tokens': 495, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_51db84afab', 'id': 'chatcmpl-C7CnHJLyf2abajeiGUnyEogsCy9mK', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--4e5d1d66-231e-43ef-bdd3-dffb07f14e97-0', usage_metadata={'input_tokens': 37, 'output_tokens': 458, 'total_tokens': 495, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %%
for res in response:
  print(res.content)
# Out:
# 서울 광장시장은 다양한 맛있는 길거리 음식으로 유명합니다. 다음은 광장시장에서 꼭 먹어봐야 할 몇 가지 길거리 음식입니다:
#
# 1. **떡볶이**: 매콤달콤한 소스에 푹 담가진 쌀떡과 어묵, 야채가 함께 나오는 인기 있는 간식입니다.
#
# 2. **순대**: 한국의 전통 순대는 돼지의 창자에 찹쌀, 당면, 채소 등을 넣어 만든 음식으로, 쫄깃한 식감이 매력적입니다. 보통 간장 소스나 고추장을 찍어 먹습니다.
#
# 3. **핫바**: 어묵으로 만든 바삭한 튀김으로, 다양한 속재료가 들어간 것이 특징입니다. 간편하게 먹기 좋고, 따뜻하게 제공됩니다.
#
# 4. **튀김**: 각종 채소와 해산물을 튀긴 음식으로, 바삭하고 고소한 맛이 일품입니다. 특히 새우튀김이 인기가 많습니다.
#
# 5. **계란빵**: 겉은 부드러운 빵에 계란이 푹 담겨 있는 간식으로, 따뜻하고 부드러운 식감이 좋습니다.
#
# 6. **야채전**: 다양한 채소를 섞어 부친 전으로, 바삭하고 담백한 맛이 특징입니다. 간장 소스와 함께 즐기면 더욱 맛있습니다.
#
# 7. **김밥**: 다양한 재료를 넣어 만든 김밥도 좋은 선택입니다. 간편하게 먹을 수 있어 길거리에서 인기입니다.
#
# 8. **과일 주스**: 신선한 과일로 만든 주스나 스무디는 더운 날씨에 상큼하게 마시기 좋은 음식입니다.
#
# 광장시장에서 다양한 길거리 음식을 즐기며 한국의 맛을 경험해 보세요!
# 서울은 데이트를 즐기기에 정말 멋진 장소가 많습니다. 분위기 좋은 곳들을 몇 가지 추천해드릴게요.
#
# 1. **한강공원**: 저녁 노을에 따라 걷거나 자전거를 탈 수 있는 아름다운 공원입니다. 특히 선유도 공원은 분위기가 좋고 아기자기한 포토존도 많아요.
#
# 2. **북촌 한옥마을**: 전통 한옥이 자아내는 고즈넉한 분위기 속에서 산책하며 서로의 이야기를 나눌 수 있는 곳입니다. 앙증맞은 찻집도 많아 차 한 잔을 즐기기에도 좋습니다.
#
# 3. **익선동**: 현대적인 감각과 전통이 어우러진 곳으로, 예쁜 카페와 레스토랑들이 많아 데이트하기 좋은 곳입니다. 각종 소품샵도 있어 구경하기에 좋습니다.
#
# 4. **가로수길**: 패션과 트렌드의 중심지로, 스타일리시한 카페와 레스토랑이 많습니다. 거리 자체도 여유롭게 걸어다니기 좋습니다.
#
# 5. **남산 서울타워**: 케이블카를 타고 올라가거나, 산책로를 따라 올라가면서 서울의 전경을 즐길 수 있습니다. 특히 해질 무렵의 경치가 아름다워 로맨틱한 분위기를 만끽할 수 있습니다.
#
# 6. **홍대**: 다양한 예술과 문화를 즐길 수 있는 곳으로, 거리공연이나 독특한 카페가 많습니다. 밤에는 활기찬 분위기 속에서 바나 클럽도 즐길 수 있습니다.
#
# 7. **이태원**: 다양한 문화가 공존하는 이곳에서는 세계 각국의 음식을 맛볼 수 있는 레스토랑도 많고, 분위기 좋은 바나 카페도 많아 색다른 데이트를 즐길 수 있습니다.
#
# 이 외에도 서울에는 많은 숨겨진 명소와 매력적인 장소가 있으니, 둘만의 특별한 추억을 만들어보세요!

# %%
messages = [
    ("system", "당신은 서울의 음식과 문화 전문가입니다."),
    ("human", "서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5개를 추천해 주세요.") 
]
response = llm.stream(messages)
for res in response:
  print(res.content, end='')
# Out:
# 서울에서 대표적인 음식을 맛볼 수 있는 훌륭한 레스토랑 5곳을 추천해 드리겠습니다.
#
# 1. **광장시장** - 다양한 한국 전통 음식을 한 곳에서 맛볼 수 있는 시장입니다. 특히 빈대떡, 김밥, 떡볶이, 순대 등을 노점에서 직접 즐길 수 있습니다. 현지의 분위기를 만끽하며 다양한 음식을 경험해보세요.
#
# 2. **옥동식** - 서울에서 유명한 설렁탕 전문점으로, 깊고 풍부한 맛의 국물이 매력적입니다. 뚝배기에서 나오는 뜨끈한 설렁탕과 함께 부드러운 양지머리 고기를 맛볼 수 있습니다.
#
# 3. **신당동 떡볶이 골목** - 다양한 떡볶이 집이 밀집해 있는 곳으로, 다양한 스타일의 떡볶이를 맛볼 수 있습니다. 매운 떡볶이, 치킨 떡볶이 등 여러 맛을 시도해볼 수 있어 맛있는 간식거리를 찾는 사람들에게 인기가 많습니다.
#
# 4. **부산아지매** - 이곳은 해산물 요리, 특히 회와 매생이국이 유명합니다. 신선한 해산물을 기본으로 한 한식 메뉴를 즐길 수 있는 좋은 장소입니다. 바다의 맛을 느끼고 싶은 분들께 추천합니다.
#
# 5. **미진** - 이곳은 정갈한 비빔밥과 전통 한정식을 경험할 수 있는 레스토랑입니다. 신선한 재료로 만든 다양한 반찬과 함께 비빔밥을 즐길 수 있어, 한국의 정통 맛을 느끼기에 좋습니다.
#
# 이 레스토랑들은 서울의 대표적인 음식 문화를 잘 보여주는 곳들입니다. 각기 다른 매력을 가진 맛집에서 서울의 다양한 음식들을 즐겨보세요!

# %% [markdown]
# # async, sync

# %%
import asyncio
import time

async def invoke_async(llm, messages):
    response = await llm.ainvoke(messages)
    print(response.content)

async def invoke_parallel(llm, messages):
    tasks = [invoke_async(llm, messages) for _ in range(10)]
    await asyncio.gather(*tasks)

# %% [markdown]
# # async

# %%
messages = [
    ("system", "당신은 서울의 음식과 문화 전문가입니다."),
    ("human", "서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5개를 추천해 주세요.") 
]
start = time.perf_counter()

await invoke_parallel(llm, messages)

end = time.perf_counter()

print(f'Elapsed time: {end - start:.2f} seconds')
# Out:
# 서울에서 대표적인 음식을 맛볼 수 있는 레스토랑 5곳을 추천해드리겠습니다.
#
# 1. **곰탕집 갑오징어 (Gopang Jip)**
#    - 대표 메뉴: 곰탕
#    - 설명: 깊고 진한 국물의 곰탕을 전문으로 하는 곳으로, 신선한 재료를 사용하여 정통 한국의 맛을 느낄 수 있습니다.
#
# 2. **서촌 동순이 (Seochon Dongsuni)**
#    - 대표 메뉴: 비빔밥
#    - 설명: 전통 비빔밥을 현대적인 감각으로 재해석한 곳으로, 신선한 채소와 다양한 고명이 어우러진 메뉴가 인기입니다.
#
# 3. **광장시장 (Gwangjang Market)**
#    - 대표 메뉴: 빈대떡, 마약김밥
#    - 설명: 서울의 전통 시장에서 다양한 한국 음식을 경험할 수 있는 곳입니다. 특히 빈대떡과 마약김밥이 유명합니다.
#
# 4. **통인시장 (Tongin Market)**
#    - 대표 메뉴: 도시락 (구입한 토큰으로 다양한 반찬 선택 가능)
#    - 설명: '도시락 카페'에서 여러 가지 반찬을 선택해 나만의 도시락을 만들어 먹을 수 있는 독특한 경험이 가능합니다.
#
# 5. **한방삼계탕 (Hanbang Samgyetang)**
#    - 대표 메뉴: 삼계탕
#    - 설명: 건강에 좋은 한방 재료를 사용하여 만든 삼계탕을 전문으로 하는 곳으로, 여름철 보양식으로 인기가 높습니다.
#
# 위의 레스토랑들은 서울에서 전통적인 한국의 맛을 느낄 수 있는 좋은 장소들이니 꼭 방문해보세요!
# 서울에서 대표적인 음식을 맛볼 수 있는 레스토랑 5곳을 추천드립니다.
#
# 1. **광장시장 (Gwangjang Market)**
#    - **추천 메뉴**: 빈대떡, 마약 김밥
#    - 전통적인 한국 시장으로, 다양한 길거리 음식을 즐길 수 있습니다. 특히 빈대떡과 함께 김밥을 곁들여 먹는 것이 유명합니다.
#
# 2. **사람들 (Saramdeul)**
#    - **추천 메뉴**: 갈비찜
#    - 전통 한식과 현대적인 감각이 어우러진 갈비찜을 제공합니다. 신선한 재료와 정성을 담아 만드는 음식이 일품입니다.
#
# 3. **삼청동 수제비 (Samcheongdong Sujebi)**
#    - **추천 메뉴**: 수제비
#    - 전통적인 수제비를 전문으로 하는 식당입니다. 고소하고 진한 육수에 담긴 수제비는 따뜻하고 위안이 되는 맛을 제공합니다.
#
# 4. **을지로 입구 초계국수 (Euljiro Ipgu Chogye Guksu)**
#    - **추천 메뉴**: 초계국수
#    - 초계국수는 찬 닭고기와 시원한 육수로 만든 전통적인 여름 별미입니다. 특히 더운 날씨에 제격인 이 음식을 맛볼 수 있습니다.
#
# 5. **한강 둔치 (Han River Park)**
#    - **추천 메뉴**: 치킨과 맥주 (치맥)
#    - 한강변에서는 피크닉과 함께 치킨과 맥주를 즐길 수 있는 많은 가게가 있습니다. 특히 오전이나 저녁에 한강의 경치를 즐기며 먹는 치킨은 서울의 여름을 느끼기에 perfect합니다.
#
# 이 외에도 서울에는 다양한 맛집이 많으니, 직접 방문하여 다양한 음식을 경험해 보시는 것도 좋습니다!
# 서울에서 대표적인 한국 음식을 맛볼 수 있는 훌륭한 레스토랑 5곳을 추천해 드리겠습니다.
#
# 1. **광장시장 (Gwangjang Market)**
#    전통 시장에서 다양한 한국 음식을 즐길 수 있습니다. 빈대떡과 족발, 마약김밥, 떡볶이 등 여러 가지 길거리 음식을 한 곳에서 맛볼 수 있는 곳입니다.
#
# 2. **다락원 (Darakhwan)**
#    전통 한정식 전문점으로, 정갈한 한정식 코스를 경험할 수 있습니다. 제철 재료를 활용한 다양한 반찬과 함께 제공되는 밥상은 한국의 식문화를 가까이서 느낄 수 있게 해줍니다.
#
# 3. **을지로 원조불고기 (Euljiro Wonjo Bulgogi)**
#    불고기의 진수를 맛볼 수 있는 곳입니다. 부드럽게 구운 고기와 함께 나오는 다양한 반찬들이 일품입니다. 현지인들이 자주 찾는 인기 있는 맛집입니다.
#
# 4. **청진동 해장국 (Cheongjin-dong Haejang-guk)**
#    해장국 전문점으로, 얼큰한 국물과 부드러운 고기가 어우러진 해장국이 유명합니다. 취향에 따라 다양한 토핑을 추가할 수 있어 개인의 입맛에 맞게 즐길 수 있습니다.
#
# 5. **명동교자 (Myeongdong Kyoja)**
#    칼국수와 만두로 유명한 맛집입니다. 직접 만든 면과 국물은 진하고 깊은 맛이 나며, 많은 사람들이 찾는 인기 있는 장소입니다. 간편하게 한국식 국수를 즐기기에 좋습니다.
#
# 이곳들은 한국 전통 음식을 대표하는 맛집들이니 서울을 방문할 때 꼭 들러보시기를 추천드립니다!
# 서울에서 대표적인 음식들을 맛볼 수 있는 레스토랑 5곳을 추천드리겠습니다.
#
# 1. **감나무집** (Gamnamu House) - **갈비찜**
#    - 갈비찜으로 유명한 이곳은 부드러운 소갈비와 풍부한 양념이 매력적입니다. 시골집 같은 아늑한 분위기에서 전통 한식을 즐길 수 있습니다.
#
# 2. **백리향** (Baekrihang) - **중식 (짜장면, 짬뽕)**
#    - 서울에서 유명한 중화요리 레스토랑으로, 정통 짜장면과 짬뽕이 특히 맛있습니다. 인테리어도 고급스러워 특별한 자리에서 식사하기 좋습니다.
#
# 3. **모수** (Mosu) - **정통 한식 코스**
#    - 현대적인 터치가 가미된 전통 한식을 제공합니다. 계절에 따라 변하는 메뉴로 제철 재료를 활용하여 식사를 즐길 수 있습니다. Michelin Guide에도 소개된 레스토랑입니다.
#
# 4. **부대찌개 해물탕 전문점** (Budaejjigae Heemooltang 전문점) - **부대찌개**
#    - 서울의 부대찌개를 대표하는 곳 중 하나입니다. 소시지와 다양한 재료가 들어간 푸짐한 국물 요리로, 술안주로도 인기가 많습니다.
#
# 5. **종로할머니부각** (Jongno Halmae Bupak) - **전 (전통 빈대떡 등)**
#    - 다양한 종류의 전과 막걸리를 즐길 수 있는 곳으로, 전통적인 맛을 그대로 재현하고 있습니다. 특히 인기 있는 메뉴는 빈대떡과 공주전입니다.
#
# 각 레스토랑은 서울의 전통 음식과 다양한 요리 스타일을 경험할 수 있는 곳이니, 한번 방문해보시길 추천드립니다!
# 서울에서 대표적인 음식을 맛볼 수 있는 레스토랑 5곳을 소개해드리겠습니다.
#
# 1. **광화문 미진**
#    - 대표 메뉴: 비빔밥
#    - 설명: 전통적인 비빔밥을 맛볼 수 있는 곳으로, 신선한 제철 재료가 사용됩니다. 비빔밥 외에도 다양한 한정식 메뉴가 있어 한국 전통 음식을 경험하기에 좋은 장소입니다.
#
# 2. **강서식당**
#    - 대표 메뉴: 불고기
#    - 설명: 불고기의 참맛을 느낄 수 있는 레스토랑으로, 풍성한 양과 깊은 맛이 특징입니다. 고기를 사랑하는 사람들에게 추천하며, 자극적이지 않은 간장이 사용되어 육즙이 가득합니다.
#
# 3. **서래갈매기**
#    - 대표 메뉴: 갈매기살
#    - 설명: 서울에서 유명한 갈매기살 구이 전문점입니다. 신선한 고기를 즉석에서 구워 먹을 수 있으며, 다양한 쌈 채소와 소스가 함께 제공되어 풍부한 맛을 즐길 수 있습니다.
#
# 4. **남서울알로이스**
#    - 대표 메뉴: 김치찌개
#    - 설명: 진하고 깊은 국물 맛을 자랑하는 김치찌개를 전문으로 하는 식당으로, 집밥 같은 편안한 분위기에서 푸짐한 한 끼를 즐길 수 있는 곳입니다.
#
# 5. **관악사**
#    - 대표 메뉴: 떡볶이
#    - 설명: 서울의 대표 길거리 음식인 떡볶이를 즐길 수 있는 곳으로, 제대로 된 밀키트 떡볶이를 경험할 수 있습니다. 달콤하고 매콤한 맛이 잘 어우러진 떡볶이가 인기입니다.
#
# 이 다섯 곳은 각각의 독특한 매력으로 서울의 대표 음식을 맛볼 수 있는 좋은 장소입니다. 즐거운 식사 되세요!
# 서울에서 대표적인 한국 음식을 맛볼 수 있는 레스토랑 5곳을 소개합니다.
#
# 1. **광장시장 (Gwangjang Market)**
#    - 다양한 전통 음식을 경험할 수 있는 서울의 역사적인 시장입니다. 빈대떡, 육회, 그리고 김밥 등 다양한 먹거리를 즉석에서 즐길 수 있습니다. 특히, 노포 스타일의 상점들이 많아 현지인처럼 식사하는 경험을 할 수 있습니다.
#
# 2. **명동교자 (Myeongdong Kyoja)**
#    - 칼국수와 만두로 유명한 이 레스토랑은 그 특별한 육수와 쫄깃한 면발로 많은 사랑을 받고 있습니다. 명동에 위치해 있어 관광객들에게 인기가 많으며, 항상 웨이팅이 있을 정도로 유명한 곳입니다.
#
# 3. **설렁탕 (Seolleongtang)**
#    - 서울의 전통적인 설렁탕을 맛볼 수 있는 대표적인 식당으로, '신선설농탕'이 있습니다. 진하고 깔끔한 국물과 부드러운 소고기가 일품입니다. 설렁탕을 밥과 함께 즐기는 것이 일반적입니다.
#
# 4. **갈비집 (Galbi Jip)**
#    - 서울의 고기를 즐길 수 있는 갈비 전문점으로, '이태원 갈비'를 추천합니다. 불고기와 갈비가 대표 메뉴이며, 매장에서 조리한 고기를 숯불에 구워 즐길 수 있습니다. 전통 반찬과 함께 푸짐한 한 끼를 경험할 수 있습니다.
#
# 5. **토속촌 (Tosokchon)**
#    - 삼계탕으로 유명한 식당으로, 특히 여름철에는 더 많은 손님으로 붐빕니다. 신선한 재료로 만든 삼계탕이 진하고 깊은 맛을 자랑하며, 건강식으로 많은 사람들이 찾습니다. 또한, 전통적인 분위기에서 식사할 수 있습니다.
#
# 이 외에도 서울은 다양한 음식 문화를 자랑하고 있으니, 각 지역에서 특색 있는 음식을 찾아보시는 것도 추천드립니다!
# 서울에서 대표적인 한국 음식을 맛볼 수 있는 레스토랑을 아래와 같이 추천드립니다:
#
# 1. **한정식 고궁**
#    - 위치: 종로구
#    - 설명: 전통 한정식으로 다양한 반찬과 주요리를 한자리에서 즐길 수 있는 곳입니다. 고궁의 분위기를 느낄 수 있는 고급스러운 인테리어와 함께 정갈한 맛을 제공합니다.
#
# 2. **을지로 곰탕**
#    - 위치: 중구
#    - 설명: 진하고 깊은 맛의 곰탕을 자랑하는 이곳은 오랜 역사를 가진 전통 곰탕집입니다. 건강한 국물과 부드러운 고기가 어우러져 얼큰한 맛을 선호하는 분들에게 추천합니다.
#
# 3. **김치찌개 전문점 '청진동 해장국'**
#    - 위치: 종로구
#    - 설명: 서울의 대표적인 해장국과 김치찌개를 판매하는 인기가 많은 식당입니다. 시원하고 얼큰한 국물은 아침 해장으로 특히 제격입니다.
#
# 4. **부암동 금수강산**
#    - 위치: 종로구
#    - 설명: 전통 한국 가정식을 현대적으로 재해석한 레스토랑입니다. 건강식과 신선한 재료를 특성으로 하여, 아늑한 분위기 속에서 식사를 즐길 수 있습니다.
#
# 5. **홍대 백종원의 골목식당**
#    - 위치: 마포구
#    - 설명: 유명 셰프 백종원이 추천한 식당 중 하나로, 다양한 한국 전통 음식을 제공합니다. 부담 없는 가격에 푸짐한 양과 맛으로 인기 있는 장소입니다.
#
# 이 외에도 서울에는 정말 다양한 전통 음식점들이 있으니, 각자 취향에 맞는 메뉴를 찾아보시길 추천드립니다!
# 서울은 다양한 전통음식과 현대적인 요리들이 어우러져 있는 도시입니다. 다음은 서울을 대표하는 음식들을 맛볼 수 있는 레스토랑 5곳을 추천합니다.
#
# 1. **조개구이집 (Yeonnam-dong)**
#    - 이곳은 한국식 조개구이를 전문으로 하는 식당으로, 신선한 조개와 함께 다양한 해산물을 구워 맛볼 수 있습니다. 그릴에 구운 조개의 담백한 맛과 함께 소주 한 잔을 곁들이면 일품입니다.
#
# 2. **왕십리프라임 (Wangsimni-prime)**
#    - 대표적인 비빔밥 전문점으로, 각종 신선한 재료를 사용하여 만든 비빔밥은 그 맛이 일품입니다. 특히 이곳의 매운 고추장 소스와 함께 비벼 먹는 비빔밥은 꼭 드셔보셔야 합니다.
#
# 3. **명동교자 (Myeongdong Kyoja)**
#    - 서울의 유명한 칼국수 전문점으로, 직접 만든 면과 육수의 깊은 맛이 매력입니다. 칼국수 외에도 만두가 특히 인기이며, 이곳에서 느끼는 따뜻한 식사가 여행의 피로를 잊게 해줍니다.
#
# 4. **광화문의 بيتزا (Gwanghwamun Pizza)**
#    - 전통적인 한국의 재료를 활용한 피자 전문점입니다. 한국의 고유한 맛과 이탈리안 피자가 혼합된 독특한 메뉴를 제공합니다. 특히 고추장 소스를 활용한 피자가 유명합니다.
#
# 5. **이태원 부대찌개 (Itaewon Budae Jjigae)**
#    - 부대찌개는 한국 전쟁 이후 만들어진 퓨전 음식으로, 햄과 소시지, 다양한 채소가 들어갑니다. 이태원에 위치한 이 식당에서는 푸짐하게 제공되는 부대찌개를 즐길 수 있으며, 다양한 사이드 메뉴도 함께 제공됩니다.
#
# 서울의 전통 음식과 현대적인 변화를 경험할 수 있는 이 레스토랑들을 방문해 보세요. 맛있는 음식과 함께 서울의 매력을 만끽하실 수 있을 것입니다!
# 서울에서 대표적인 음식을 맛볼 수 있는 레스토랑 다섯 곳을 추천해 드리겠습니다.
#
# 1. **광장시장 (Gwangjang Market)**
#    - **특징**: 서울 전통 시장 중 하나로, 빈대떡, 육회, 김밥 등 다양한 한국 전통 음식을 한 자리에서 맛볼 수 있습니다. 각종 포장마차와 음식점이 밀집해 있어 현지 분위기를 느끼기에 좋은 장소입니다.
#
# 2. **노포참숯구이 (Nopo Charcoal Grill)**
#    - **특징**: 전통 한우를 사용한 갈비와 숯불구이가 주 메뉴입니다. 질 좋은 고기를 제공하며, 특별한 소스와 함께 즐길 수 있습니다. 따뜻한 분위기에서 가족과 함께 식사하기 좋은 장소입니다.
#
# 3. **부대찌개 1번가 (Budae Jjigae 1st Street)**
#    - **특징**: 부대찌개가 유명한 식당으로, 햄, 소시지, 스팸 등을 넣어 끓이는 한국식 스튜입니다. 매콤하고 진한 국물이 일품이며, 테이블에서 즉석에서 조리되는 모습을 볼 수 있습니다.
#
# 4. **맘모스베이커리 (Mammoth Bakery)**
#    - **특징**: 서울에서 인기 있는 베이커리 중 하나로, 다양한 종류의 빵과 디저트를 제공합니다. 특히 그들의 앙버터(찐빵과 팥, 버터가 조화된 음식)는 꼭 한 번 경험해 볼 만합니다.
#
# 5. **송추 닭갈비 (Songchu Dakgalbi)**
#    - **특징**: 닭갈비의 전통적인 맛을 유지하면서도 현대적인 인테리어로 개조된 식당입니다. 매콤한 양념의 닭고기를 철판에 볶아내며, 다양한 채소와 함께 즐길 수 있습니다.
#
# 이 외에도 서울에는 다양한 전통 음식과 현대적인 맛을 제공하는 레스토랑이 많습니다. 즐거운 식사 시간 되세요!
# 서울에서 대표적인 음식을 맛볼 수 있는 레스토랑 다섯 곳을 추천해드릴게요.
#
# 1. **조선식당 (Josen Restaurant)**
#    - 위치: 광화문
#    - 특징: 전통 한정식을 경험할 수 있는 곳으로, 한국의 전통 맛과 분위기를 느낄 수 있는 고급스러운 식당입니다. 다양한 찬과 함께 든든한 메인 요리를 제공합니다.
#
# 2. **백리향 (Baekrihyang)**
#    - 위치: 종로구
#    - 특징: 중식과 한식을 접목한 퓨전 요리를 제공하며, 특히 짜장면과 볶음밥으로 유명합니다. 건강하고 신선한 재료를 사용하여 전통적인 맛을 현대적으로 재해석합니다.
#
# 3. **밀 면 (Mill Myeon)**
#    - 위치: 방배동
#    - 특징: 손으로 만든 면이 특징인 비빔내면과 일본식 우동이 인기 있는 곳입니다. 신선한 재료로 만든 면 요리를 제공합니다.
#
# 4. **토속촌 삼계탕 (Tosokchon Samgyetang)**
#    - 위치: 종로구
#    - 특징: 삼계탕으로 유명한 곳으로, 특히 보양식으로 인기가 높습니다. 인삼과 찹쌀, 약재와 함께 조리된 닭이 깊은 맛을 자랑합니다.
#
# 5. **광장시장 (Gwangjang Market)**
#    - 위치: 종로구
#    - 특징: 다양한 한국 전통 음식을 한 곳에서 맛볼 수 있는 재래시장의 명소입니다. 빈대떡, 떡볶이, 김밥, 순대 등 다양한 먹거리를 즐길 수 있습니다.
#
# 이곳들은 서울의 다양한 전통 음식을 맛볼 수 있는 훌륭한 선택지입니다. 즐거운 식사 되세요!
# Elapsed time: 9.67 seconds

# %%
# sync 호출 시간 비교 5 times

# %% [markdown]
# pip install meilisearch

# %%
import meilisearch
client = meilisearch.Client('http://127.0.0.1:7700', '4L6ODo1rTEROnXZg_MN6YQFtUl6REBZlEyWeQ4KyxLA')

# %%
client

# %%
import pandas as pd
df = pd.read_csv('nasdaq_screener_1755789601709.csv', na_filter=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7008 entries, 0 to 7007
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Symbol      7008 non-null   object
#  1   Name        7008 non-null   object
#  2   Last Sale   7008 non-null   object
#  3   Net Change  7008 non-null   float64
#  4   % Change    7008 non-null   object
#  5   Market Cap  7008 non-null   object
#  6   Country     7008 non-null   object
#  7   IPO Year    7008 non-null   object
#  8   Volume      7008 non-null   int64
#  9   Sector      7008 non-null   object
#  10  Industry    7008 non-null   object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 602.4+ KB

# %%
df['id'] = df['Symbol'].str.strip().replace(r'[/^]', '_', regex=True) 
df.head(3)
# Out:
#   Symbol                                               Name Last Sale  \
# 0      A             Agilent Technologies Inc. Common Stock   $117.95
# 1     AA                    Alcoa Corporation Common Stock     $29.24
# 2   AACB  Artius II Acquisition Inc. Class A Ordinary Sh...    $10.12
#
#    Net Change % Change      Market Cap        Country IPO Year  Volume  \
# 0       -1.16  -0.974%  33505434668.00  United States     1999   96792
# 1       -0.09  -0.307%   7570666501.00  United States     2016  490423
# 2       -0.02  -0.197%            0.00  United States     2025    5002
#
#         Sector                                          Industry    id
# 0  Industrials  Biotechnology: Laboratory Analytical Instruments     A
# 1  Industrials                                          Aluminum    AA
# 2                                                                 AACB

# %%
client.index('nasdaq').add_documents( df.to_dict(orient='records'), primary_key = 'id')
# Out:
# TaskInfo(task_uid=3, index_uid='nasdaq', status='enqueued', type='documentAdditionOrUpdate', enqueued_at=datetime.datetime(2025, 8, 22, 5, 51, 42, 56433))

# %%
client.index('nasdaq').search('appl')
# Out:
# {'hits': [{'id': 'AAOI',
#    'Symbol': 'AAOI',
#    'Name': 'Applied Optoelectronics Inc. Common Stock',
#    'Last Sale': '$22.48',
#    'Net Change': 0.55,
#    '% Change': '2.508%',
#    'Market Cap': '1401714458.00',
#    'Country': 'United States',
#    'IPO Year': '2013',
#    'Volume': 1097765,
#    'Sector': 'Technology',
#    'Industry': 'Semiconductors'},
#   {'id': 'AAPL',
#    'Symbol': 'AAPL',
#    'Name': 'Apple Inc. Common Stock',
#    'Last Sale': '$225.41',
#    'Net Change': -0.6,
#    '% Change': '-0.265%',
#    'Market Cap': '3345172309900.00',
#    'Country': 'United States',
#    'IPO Year': '1980',
#    'Volume': 7475644,
#    'Sector': 'Technology',
#    'Industry': 'Computer Manufacturing'},
#   {'id': 'AIT',
#    'Symbol': 'AIT',
#    'Name': 'Applied Industrial Technologies Inc. Common Stock',
#    'Last Sale': '$260.5831',
#    'Net Change': -1.8769,
#    '% Change': '-0.715%',
#    'Market Cap': '9837779963.00',
#    'Country': 'United States',
# ...
